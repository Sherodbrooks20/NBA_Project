# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\shero\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\shero\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\shero\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\shero\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\shero\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.api as sm
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from scipy.stats import zscore

# %%
# reading in the major csv files, to work on them and edit the datasets
df_sea = pd.read_csv(r"C:\Users\shero\Downloads\NBA Project\Copy of seasons(updated).csv")
df_cpl = pd.read_csv(r"C:\Users\shero\Downloads\NBA Project\Copy of players(updated).csv")
df_phw = pd.read_csv(r"C:\Users\shero\Downloads\NBA Project\Copy of players_height_weight(updated).csv")
df_ndd = pd.read_csv(r"C:\Users\shero\Downloads\NBA Project\nba_draft_data.csv")

# reading in sql edited csv files, to work on them and edit the datasets
df_ms = pd.read_csv(r"C:\Users\shero\Downloads\NBA Project\main_stats.csv")
df_pl = pd.read_csv(r"C:\Users\shero\Downloads\NBA Project\players.csv")
df_pm = pd.read_csv(r"C:\Users\shero\Downloads\NBA Project\players_measure.csv")
df_as = pd.read_csv(r"C:\Users\shero\Downloads\NBA Project\advanced_stats_temp.csv")

#df_sea
#df_cpl
#df_phw
#df_ndd

#df_ms
#df_pl
#df_pm
#df_as

# %%
# looking at the datatypes of each dataset, to get a better understanding of the dataset and how I should edit/analyze the data
#df_sea.info()
#df_cpl.info()
#df_phw.info()
#df_ndd.info()

#df_ms.info()
#df_pl.info()
#df_pm.info()
#df_as.info()

# %%
#updating the positions to match each other across datasets, to make it easier to merge them 

df_sea['Pos'] = df_sea['Pos'].replace({'PG':'Guard', 'SG':'Guard', 'SF': 'Wing', 'PF': 'Big', 'C':'Big'})
df_cpl['position'] = df_cpl['position'].replace({'PG':'Guard', 'SG':'Guard', 'SF': 'Wing', 'PF': 'Big', 'C':'Big'})
df_as['Pos'] = df_as['Pos'].replace({'PG':'Guard', 'SG':'Guard', 'SF': 'Wing', 'PF': 'Big', 'C':'Big'})

#updating columns name to merge the dataets
df_sea = df_sea.rename(columns={"Player":"player"})
df_cpl = df_cpl.rename(columns={"name":"player"})
df_phw = df_phw.rename(columns={"Player":"player"})

df_pl = df_pl.rename(columns={"name": "player"})
df_as = df_as.rename(columns={"Player":"player"})

df_ndd = df_ndd.rename(columns={'pts_per_g':'ppg'})
df_ndd = df_ndd.rename(columns={'fg_pct':'fg'})
df_ndd = df_ndd.rename(columns={'fg3_pct':'3p'})
df_ndd = df_ndd.rename(columns={'ft_pct':'ft'})
df_ndd = df_ndd.rename(columns={'mp_per_g':'mpg'})
df_ndd = df_ndd.rename(columns={'trb_per_g':'rbg'})
df_ndd = df_ndd.rename(columns={'ast_per_g':'asg'})

# %%
# merge multiple datasets, to get one dataset that has all I need to start analyzing the data

#df_full_player_demos
df_fpw = df_ms.merge(df_pl, on = 'player', how = "outer").merge(
    df_pm, on = 'player', how = "outer").merge(
    df_as, on = 'player', how = "outer").merge(
    df_ndd, on = 'player', how = "outer")

# shows all columns, so I can select the ones I want
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

df_fpw = df_fpw.rename(columns= {'college_x': 'college', 'g_x':'g', '2p_x':'2p',
'ppg_x':'ppg', 'asg_x':'asg','rbg_x':'rbg','fg_x':'fg','ft_x':'ft', 'mpg_x':'mpg'})

# filtering the columns desired
df_fpw = df_fpw[['player','pick_overall', 'college', 'birth_state','height','weight', 'position', 
"ppg", 'asg', 'rbg', 'fg', '3P','2p', 'ft', 'stl', 'blk', 'g', 'gs', 'mpg']]

# cleaning up the merged column names

#df_fpw.head(1)

# %%
# remove duplicates from datasets
df_fpw = df_fpw.groupby('player', as_index = False).agg({ 'pick_overall':'first','college':'first', 'height':'first', 'weight':'first', 
    'position':'first', 'ppg':'mean', 'asg':'mean', 'rbg':'mean', 'fg':'mean', 
    '3P':'mean', '2p': 'mean', 'ft':'mean', 'stl':'mean', 'blk':'mean','g':'mean','gs':'mean', 'mpg':'mean'})

df_as = df_as.groupby('player', as_index = False).agg({
    'Pos':'first','PER':'mean', 'TS':'mean', 'USG':'mean', 
    'WS':'mean', 'FG':'mean', '3p':'mean', '2p':'mean', 'eFG%':'mean', 
    'FT':'mean'})

#df_sea = df_sea.groupby('player', as_index = False).agg({  'Pos': 'first', 'PER': 'mean',  'TS%': 'mean', 'USG%': 'mean', 'WS': 'mean', 'FG%':'mean',
    #'3PPercentage':'mean','2p/Dis':'mean','eFG%':'mean','FT/Dis':'mean','RBG':'mean','ASG':'mean','STL/Dis':'mean','BLK/Dis':'mean','TPG':'mean',
    #'PFG':'mean','PPG':'mean'})

# %%
#filling NaN values with 0, to get a cleaner looking dataset
df_sea = df_sea.fillna(0)
df_cpl = df_cpl.fillna(0)
df_phw = df_phw.fillna(0)
df_ndd = df_ndd.fillna(0)

df_ms = df_ms.fillna(0)
df_pl = df_pl.fillna(0)
df_pm = df_pm.fillna(0)
df_as = df_as.fillna(0)

df_fpw = df_fpw.fillna(0)
df_pick = df_pick.fillna(0)

# %%
# remove rows the have no major stats data

df_fpw = df_fpw[(df_fpw['g'] > 0)]

# assigning positions to rows that don't have them by height
def assign_position(height):
    if height < 6.3:
        return 'Guard'
    elif 6.3 < height < 6.8:
        return 'Wing'
    else:
        return 'Big'
        
df_fpw['position'] = df_fpw.apply(lambda row: assign_position(row['height']) if row['position'] == 0 else row['position'], axis =1)

# %%
# position based analysis

# getting descriptive stats by position -------------------------
Pos_stats = df_fpw.groupby('position')[['ppg','asg','rbg','stl','blk']].agg(['mean', 'median', 'min', 'max'])

# position counts ---------------------------
Pos_count = df_fpw['position'].value_counts()

# creating a box plot to visualize data -----------------------

#plt.figure(figsize = (10,6))
#sns.boxplot(x=df_fpw['position'], y= df_fpw['ppg'], palette='Set2')
#plt.title('Dis of ppg by pos')
#plt.xlabel('POS')
#plt.ylabel('PPG')
#plt.show()


# shooting stats by pos

#Shooting = df_fpw.groupby('position').agg({ '3P':'mean','2p':'mean','fg': 'mean', 'ft': 'mean'})
    
# bar chart for shooting stats-----------------------

#Shooting.plot(kind = 'bar', figsize=(12,5), colormap = 'coolwarm')
#plt.title('Shooting Efficiency by Position')
#plt.xlabel('Position')
#plt.xticks(rotation=0)
#plt.ylabel('Shooting Percentage')
#plt.show()

# separate starters and bench players ---------------------
# Starters = df_fpw[(df_fpw['gs'] >= 41)]
# Bench = df_fpw[(df_fpw['gs'] < 41)]


#shoot_starters = df_fpw[(df_fpw['gs'] >= 41)].groupby('position').agg({ '3P':'mean','2p':'mean','fg': 'mean', 'ft': 'mean'})
#shoot_bench = df_fpw[(df_fpw['gs'] < 41)].groupby('position').agg({ '3P':'mean','2p':'mean','fg': 'mean', 'ft': 'mean'})

# z-score -----------------------
# df_fpw['ppg_z'] = df_fpw.groupby('position')['ppg'].transform(zscore)

# outliers = df_fpw[df_fpw['ppg_z'] > 2][['player', 'position', 'ppg', 'ppg_z']]

# time series ------------------------
#Trend_Pos_stats = df_sea.groupby(['Year','Pos'])[['ppg','asg','rbg','stl','blk']].agg(['mean'}).unstack()

#Trend_Pos_PPG = df_sea.groupby(['Year','Pos'])[['PPG']].agg(['mean']).unstack()

#Trend_Pos_PPG.plot(figsize=(10,5), marker = 'o')
#plt.title('PPG Stats Trends by position over time')
#plt.xlabel('Year')
#plt.ylabel('Major Stats')
#plt.legend(title='Position')
#plt.show()

# %%
# Draft pick analysis

# get dataset for pick analysis
df_pick = df_ndd.merge(df_as, on='player', how = 'left').merge(df_pm, on='player', how = 'left')
df_pick = df_pick.fillna(0)


# filter columns
df_pick = df_pick[['player','pick_overall', 'team_id','college_name','height','weight', 'seasons', 'Pos', 
"ppg", 'asg', 'rbg', 'fg', '3p_y','2p', 'ft', 'g', 'USG', 'PER', 'ws', 'bpm', 'vorp', 'TS', 'birth_state']]

# filter and groupby pick
pick = df_pick[df_pick['pick_overall'] <= 60]
pick_ppg = pick.groupby('pick_overall', as_index = False)['ppg'].mean()

df_pick_p = df_pick[(df_pick['PER'] != 0) & (df_pick['pick_overall'] <= 60)]
pick_per = df_pick_p.groupby('pick_overall', as_index = False)['PER'].mean()

# visualize the data

# scatter plot of ppg by pick
#plt.scatter(pick_ppg['pick_overall'], pick_ppg['ppg'])
#plt.xlabel('pick_overall')
#plt.ylabel('PPG')
#plt.title('PPG Stats Trends by pick overall')
#plt.show()

# scatter of PER by pick
#plt.scatter(pick_per['pick_overall'], pick_per['PER'])
#plt.xlabel('pick_overall')
#plt.ylabel('PER')
#plt.title('PER Trends by pick overall')
#plt.show()

# see which teams draft the best scorers

team = pick_p
team_p = team.groupby('team_id', as_index = False)[['ppg', 'PER']].mean()
team_p = team_p.sort_values(by='ppg', ascending = False)

#team_p

# updating players without a position based on height
def assign_position(height):
    if height < 6.3:
        return 'Guard'
    elif 6.3 < height < 6.8:
        return 'Wing'
    else:
        return 'Big'
        
df_pick['Pos'] = df_pick.apply(lambda row: assign_position(row['height']) if row['Pos'] == 0 else row['Pos'], axis =1)

#sns.boxplot(x=df_pick['Pos'], y = df_pick['ppg'], hue=pd.cut(df_pick['pick_overall'], bins = [1, 10, 30, 60]))

# longevity

#sns.lineplot(x=pick['pick_overall'], y=pick['seasons'])
#plt.title('Seasons Played by Pick Number')
#plt.show()

# bust rate
def cat_pick(pick_):
    if pick_ <= 10:
        return 'Top 10'
    elif pick_ <= 20:
        return 'Mid 1st round'
    elif pick_ <= 30:
        return 'Late 1st round'
    else:
        return '2nd round'

df_pick['pick_range'] = df_pick['pick_overall'].apply(cat_pick)
pick_order = ['Top 10', 'Mid 1st round', 'Late 1st round', '2nd round']

df_pick['PER'] = df_pick.apply(
    lambda row: df_pick[(df_pick['Pos'] == row['Pos']) & (df_pick['pick_range'] == row['pick_range'])]['PER'].median() 
    if row['PER'] == 0 else row['PER'], axis=1 )
#df_pick['pick_range'] = pd.Categorical(df_pick['pick_range'], categories = pick_order, ordered = True)


#bust_rates = df_pick.groupby('pick_range')['bust'].mean().reset_index()
#bust_rates.columns = ['pick_range', 'bust_rate']
#bust_rates.sort_values(by='bust_rate', ascending = True)


#plt.figure(figsize=(8,5))
#sns.barplot(x=bust_rates['pick_range'], y=bust_rates['bust_rate'] * 100, palette = 'coolwarm', order = pick_order)
#plt.xlabel('Draft Pick Range')
#plt.ylabel('Bust Rate')
#plt.title('NBA draft bust rates by pick range')
#plt.ylim(0,70)
#plt.show()

# can show the bust rate by position and height

# use z-score to see which players outperformed and underpeformed
df_pick['per_z'] = df_pick.groupby('pick_range')['PER'].transform(lambda x: zscore (x, ddof=1))

def perf_cat(z):
    if z > 1.5:
        return 'Overperformed'
    elif z < -1.5:
        return 'Underperformed'
    else:
        return 'Average'

df_pick['per_p'] = df_pick['per_z'].apply(perf_cat)
per_filter = df_pick[df_pick['PER'] != 0]
df_pick_z = per_filter[['player', 'pick_overall', 'pick_range', 'PER', 'per_z', 'per_p']]

ops = df_pick_z[(df_pick_z['per_p'] == 'Overperformed')]
#ops

df_pick['bust'] = (
(df_pick['ppg'] < df_pick.groupby('pick_range')['ppg'].transform('mean') - 1.5 * df_pick.groupby('pick_range')['ppg'].transform('std')) | \
(df_pick['PER'] < df_pick.groupby('pick_range')['PER'].transform('mean') - 1.5 * df_pick.groupby('pick_range')['PER'].transform('std')) | \
(df_pick['seasons'] < 3))

df_pick['star'] = (
(df_pick['ppg'] > df_pick.groupby('pick_range')['ppg'].transform('mean') + 1.5 * df_pick.groupby('pick_range')['ppg'].transform('std')) &
(df_pick['PER'] > df_pick.groupby('pick_range')['PER'].transform('mean') + 1.5 * df_pick.groupby('pick_range')['PER'].transform('std')) &
(df_pick['PER'] != 0) &
(df_pick['seasons'] > 3))
# extra- college, birth state, more height , more pos

# %%
# Correlation analysis

#
corr_pick = per_filter[['pick_overall', 'ppg', 'TS' ,'PER', 'ws', 'bpm', 'vorp', 'USG']]

corr_m = corr_pick.corr()

# 
corr_pos = per_filter[['Pos', 'ppg', 'TS' ,'PER', 'ws', 'bpm', 'vorp', 'USG']]

#corr_m2 = corr_pos.corr()

# %%
# Create archetypes by clustering

stats = per_filter[['ppg', 'PER', 'TS', 'USG', 'ws', 'bpm', 'vorp']]

df_clus = stats.copy()

scaler = StandardScaler()
df_clus_scal = scaler.fit_transform(df_clus)

kmeans = KMeans(n_clusters = 3, random_state = 42, n_init = 10)
df_clus['cluster'] = kmeans.fit_predict(df_clus_scal)

#df_clus['cluster'].value_counts()

#df_clus.groupby('cluster')[['ppg', 'PER', 'TS', 'USG', 'ws', 'bpm', 'vorp']]

#plt.figure(figsize = (10,6))
#sns.scatterplot(x=df_clus['ppg'], y = df_clus['PER'], hue =df_clus['cluster'], palette = 'viridis')
#plt.xlabel('PPG')
#plt.ylabel('PER')
#plt.title('NBA Player Cluster')
#plt.show()

# %%
# export datasets to excel files

#df_sea.to_excel(r"C:\Users\shero\Downloads\sea.xlsx", index= False)
#df_cpl.to_excel(r"C:\Users\shero\Downloads\cpl.xlsx", index= False)
#df_phw.to_excel(r"C:\Users\shero\Downloads\phw.xlsx", index= False)
#df_ndd.to_excel(r"C:\Users\shero\Downloads\ndd.xlsx", index= False)

#df_ms.to_excel(r"C:\Users\shero\Downloads\ms.xlsx", index= False)
#df_pl.to_excel(r"C:\Users\shero\Downloads\pl.xlsx", index= False)
#df_pm.to_excel(r"C:\Users\shero\Downloads\pm.xlsx", index= False)
#df_as.to_excel(r"C:\Users\shero\Downloads\as.xlsx", index= False)

#df_fpw.to_excel(r"C:\Users\shero\Downloads\fpw.xlsx", index= False)
df_pick.to_excel(r"C:\Users\shero\Downloads\pick.xlsx", index= False)
#df_pick_p.to_excel(r"C:\Users\shero\Downloads\pick_p.xlsx", index= False)

# %%
df_fpw_gs = df_fpw[(df_fpw['gs'].isna() | (df_fpw['gs'])) == 0 & (df_fpw['g'] == 0)]

df_fpw_gs
# Out:
#                     player  pick_overall  \
# 8             Aaron Brooks          26.0
# 12             Aaron James           0.0
# 18           Abdul Jeelani           0.0
# 28           Adrian Branch          46.0
# 29         Adrian Caldwell           0.0
# 31         Adrian Dantley*           0.0
# 43             Al Eberhard           0.0
# 48           Al Harrington          25.0
# 61              Al Skinner           0.0
# 68          Alaa Abdelnaby          25.0
# 70              Alan Hardy           0.0
# 74           Alan Williams           0.0
# 78              Alec Burks          12.0
# 87            Alex Bradley          86.0
# 90           Alex English*           0.0
# 108      Alfredrick Hughes          14.0
# 109          Allan Bristow           0.0
# 115          Allen Leavell         104.0
# 118         Alonzo Bradley          29.0
# 123             Alton Ford          50.0
# 125            Alvan Adams           4.0
# 130            Alvin Scott         136.0
# 135           Amir Johnson          56.0
# 136       Anderson Varejao          30.0
# 137       Andrae Patterson          46.0
# 141            Andre Brown           0.0
# 146         Andre McCarter         136.0
# 154        Andre Wakefield         107.0
# 162           Andrew Bynum          10.0
# 165       Andrew Goudelock          46.0
# 170           Andrew Toney           8.0
# 183            Andy Walker         111.0
# 191        Anthony Bennett           1.0
# 193          Anthony Bowie          66.0
# 198      Anthony Frederick         133.0
# 203          Anthony Mason          53.0
# 206         Anthony Parker          21.0
# 211        Anthony Roberts          21.0
# 220         Antoine Wright          15.0
# 227           Antonio Lang          29.0
# 231           Archie Clark           0.0
# 233         Archie Goodwin          29.0
# 239          Armon Johnson          34.0
# 240            Armond Hill           9.0
# 241        Arnett Moultrie          27.0
# 260         Artis Gilmore*           0.0
# 270           Audie Norris          37.0
# 273            Austin Carr           0.0
# 277          Avery Bradley          19.0
# 278          Avery Johnson           0.0
# 281         B.J. Armstrong          18.0
# 287            Baron Davis           3.0
# 288          Barry Clemens           0.0
# 298            Bart Kofoed         107.0
# 301         Bayard Forrest          54.0
# 315           Ben Poquette          36.0
# 319               Ben Uzoh           0.0
# 320            Ben Wallace           0.0
# 327          Bernard King*           0.0
# 329       Bernard Thompson          19.0
# 331           Bernie Fryer           0.0
# 339          Bill Bradley*           0.0
# 341           Bill Bridges           0.0
# 345        Bill Cartwright           3.0
# 359           Bill Hanzlik          20.0
# 365             Bill Jones           0.0
# 367          Bill Laimbeer          65.0
# 368             Bill Ligon           0.0
# 369            Bill Martin          26.0
# 378         Bill Robinzine          10.0
# 390           Bill Walton*           0.0
# 392        Bill Willoughby          19.0
# 395      Billy Cunningham*           0.0
# 397          Billy Donovan          68.0
# 403           Billy Knight           0.0
# 404         Billy McKinney         115.0
# 406           Billy Paultz           0.0
# 407              Billy Ray           0.0
# 409             Billy Reid          98.0
# 413         Billy Thompson          19.0
# 415            Bingo Smith           0.0
# 416           Bird Averitt           0.0
# 425               Bo Ellis          17.0
# 428               Bo Lamar           0.0
# 436            Bob Bigelow          13.0
# 443         Bob Carrington          28.0
# 448          Bob Dandridge           0.0
# 456            Bob Elliott          42.0
# 465              Bob Gross          25.0
# 466             Bob Hansen          54.0
# 474           Bob Kauffman           0.0
# 479            Bob Lanier*           0.0
# 482               Bob Love           0.0
# 485            Bob McAdoo*           0.0
# 492               Bob Nash           0.0
# 516              Bob Weiss           0.0
# 518          Bob Wilkerson          11.0
# 525          Bobby Cattage         165.0
# 534            Bobby Jones          37.0
# 538           Bobby Phills          45.0
# 547           Bobby Wilson           0.0
# 552            Bonzi Wells          11.0
# 560             Brad Davis          15.0
# 561           Brad Holland          14.0
# 563            Brad Miller           0.0
# 571      Brandon Armstrong          23.0
# 573         Brandon Davies           0.0
# 602         Brian Quinnett          50.0
# 604           Brian Rowsom          34.0
# 608           Brian Taylor           0.0
# 609          Brian Winters           0.0
# 621            Bruce Seals          21.0
# 630             Bryce Drew          16.0
# 631            Bryn Forbes           0.0
# 646         Bud Stallworth           0.0
# 652            Butch Beard           0.0
# 654           Butch Carter          37.0
# 655            Butch Feher          33.0
# 658              Butch Lee          10.0
# 662             Byron Beck           0.0
# 663          Byron Dinkins           0.0
# 668             C.J. Kupec          56.0
# 669          C.J. McCollum          10.0
# 671            C.J. Watson           0.0
# 674            Cal Bowdler          17.0
# 678         Caldwell Jones           0.0
# 682         Calvin Garrett          47.0
# 685         Calvin Murphy*           0.0
# 686            Calvin Natt           8.0
# 690          Campy Russell           0.0
# 691           Carey Scurry          37.0
# 699            Carl Landry          31.0
# 702             Carl Nicks          23.0
# 704            Carl Thomas           0.0
# 709           Carlos Clark          91.0
# 719         Casey Jacobsen          22.0
# 722         Cazzie Russell           0.0
# 727        Cedric Ceballos          48.0
# 732         Cedric Maxwell          12.0
# 734        Cedrick Hordges          49.0
# 737             Chad Kinch           0.0
# 747         Charles Dudley           0.0
# 751        Charles Johnson           0.0
# 754       Charles O'Bannon          31.0
# 758    Charles Shackleford          32.0
# 760         Charles Thomas           0.0
# 765          Charlie Criss           0.0
# 772          Charlie Scott           0.0
# 773         Charlie Sitton          38.0
# 790           Chet Walker*           0.0
# 805         Chris Crawford          50.0
# 810             Chris Ford           0.0
# 811           Chris Garner           0.0
# 818          Chris Johnson           0.0
# 841             Chris Welp          16.0
# 856            Chuck Hayes           0.0
# 860           Chuck Nevitt          63.0
# 865            Chuck Terry           0.0
# 866         Chuck Williams           0.0
# 868          Chucky Atkins           0.0
# 874           Clarence Kea         169.0
# 880           Claude Terry           0.0
# 882           Clay Johnson         110.0
# 884           Clem Haskins           0.0
# 885         Clemon Johnson          44.0
# 894            Cliff Meely           0.0
# 895        Cliff Pondexter           0.0
# 896         Cliff Robinson          11.0
# 899           Clifford Ray           0.0
# 900      Clifford Robinson          36.0
# 904       Clint Richardson          36.0
# 906          Clinton Smith          97.0
# 907        Clinton Wheeler         150.0
# 911              Clyde Lee           0.0
# 914            Clyde Mayes          22.0
# 915          Coby Dietrick           0.0
# 918           Cole Aldrich          11.0
# 921           Conner Henry          89.0
# 924        Connie Hawkins*           0.0
# 925          Connie Norman           0.0
# 931          Corey Crowder           0.0
# 932           Corey Gaines          65.0
# 934         Corey Williams          33.0
# 936          Corky Calhoun           0.0
# 940         Cornell Warner           0.0
# 943         Cory Alexander          29.0
# 944         Cory Blackwell          28.0
# 946           Cory Higgins           0.0
# 959           Craig Dykema          66.0
# 960             Craig Ehlo          48.0
# 962             Craig Neal          71.0
# 964          Craig Shelton          28.0
# 972           Curtis Perry           0.0
# 973            Curtis Rowe           0.0
# 980        D.J. Strawberry          59.0
# 983         DaJuan Summers          35.0
# 992         Dale Schlueter           0.0
# 994        Dalibor Bagaric          24.0
# 1002         Damir Markota          59.0
# 1009          Dan Anderson           0.0
# 1011            Dan Dickau          28.0
# 1016            Dan Issel*           0.0
# 1019            Dan Langhi          31.0
# 1024        Dan Roundfield          28.0
# 1063         Darko Milicic           2.0
# 1064       Darnell Hillman           0.0
# 1066           Darnell Mee          34.0
# 1070     Darrell Armstrong           0.0
# 1074      Darrell Griffith           2.0
# 1077        Darrell Walker          12.0
# 1079           Darren Daye          57.0
# 1085        Darryl Dawkins           5.0
# 1089           Darwin Cook          70.0
# 1092            Dave Bing*           0.0
# 1096          Dave Corzine          18.0
# 1098          Dave Cowens*           0.0
# 1105        Dave Greenwood           2.0
# 1109         Dave Jamerson          15.0
# 1110          Dave Johnson          26.0
# 1113           Dave Meyers           2.0
# 1118          Dave Robisch           0.0
# 1123         Dave Twardzik           0.0
# 1124             Dave Wohl           0.0
# 1126        David Andersen          36.0
# 1134            David Noel          39.0
# 1137          David Rivers          25.0
# 1144       David Thompson*           0.0
# 1146          David Vaughn          25.0
# 1148          David Wesley           0.0
# 1159          DeJuan Wheat          51.0
# 1168        DeWayne Scales          36.0
# 1170         Dean Meminger           0.0
# 1172           Dean Tolson           0.0
# 1178           Del Beshore           0.0
# 1180            Dell Curry          15.0
# 1188         Dennis Awtrey           0.0
# 1189           Dennis Bell           0.0
# 1191          Dennis DuVal           0.0
# 1198       Dennis Johnson*           0.0
# 1202       Dennis Schroder          17.0
# 1208      Denzel Valentine           0.0
# 1219         Derrek Dickey           0.0
# 1221         Derrick Brown          40.0
# 1223      Derrick Caracter          58.0
# 1226          Derrick Dial          52.0
# 1246           Devin Brown           0.0
# 1260         Deyonta Davis           0.0
# 1262        Diante Garrett           0.0
# 1273            Dick Gibbs           0.0
# 1291           Dick Snyder           0.0
# 1294              Dick Van           0.0
# 1309      Dionte Christmas           0.0
# 1322             Don Adams           0.0
# 1329              Don Buse           0.0
# 1332            Don Chaney           0.0
# 1333           Don Collins          18.0
# 1336              Don Ford          92.0
# 1346           Don Nelson*           0.0
# 1355             Don Smith           0.0
# 1358          Donald Royal          52.0
# 1369        Donnie Freeman           0.0
# 1370        Donny Marshall          39.0
# 1372           Donta Smith          34.0
# 1381            Doron Lamb          42.0
# 1384          Doug Collins           0.0
# 1385          Doug Edwards          15.0
# 1388              Doug Lee          35.0
# 1389        Doug McDermott          11.0
# 1392             Doug Roth          41.0
# 1395             Doug West          38.0
# 1397         Dragan Bender           0.0
# 1401      Drazen Petrovic*           0.0
# 1406          Duane Cooper          36.0
# 1407         Duane Ferrell           0.0
# 1411         Duck Williams          96.0
# 1412        Dudley Bradley          13.0
# 1416          Dwayne Jones           0.0
# 1424          Dwight Davis           0.0
# 1426          Dwight Jones           0.0
# 1431         E'Twaun Moore          55.0
# 1432          E.C. Coleman           0.0
# 1435            Earl Clark          14.0
# 1436          Earl Cureton          58.0
# 1438            Earl Evans         157.0
# 1445          Earl Monroe*           0.0
# 1447            Earl Tatum          21.0
# 1448           Earl Watson          39.0
# 1449         Earl Williams           0.0
# 1479            Ed Ratleff           0.0
# 1489           Eddie House          37.0
# 1491         Eddie Johnson          49.0
# 1493          Eddie Jordan          33.0
# 1500        Eddie Phillips          21.0
# 1503           Edgar Jones          31.0
# 1510      Efthimi Rentzias          23.0
# 1512        Elden Campbell          27.0
# 1519          Elliot Perry          37.0
# 1525          Elmore Smith           0.0
# 1532          Elvin Hayes*           0.0
# 1535         Emanual Davis           0.0
# 1538           Enes Kanter           3.0
# 1543         Eric Fernsten          62.0
# 1546          Eric Leckner          17.0
# 1550            Eric Money           0.0
# 1553          Eric Murdock          21.0
# 1558            Eric White          65.0
# 1570      Ernie DiGregorio           0.0
# 1571        Ernie Grunfeld          11.0
# 1581           Etan Thomas          12.0
# 1587     Everette Stephens          31.0
# 1591       Fabricio Oberto           0.0
# 1593          Fatty Taylor           0.0
# 1596          Fennis Dembo          30.0
# 1603          Foots Walker           0.0
# 1617          Frank Kornet          30.0
# 1622        Frank Oleynick          12.0
# 1634       Frankie Sanders          20.0
# 1636            Fred Brown           0.0
# 1637           Fred Carter           0.0
# 1641           Fred Foster           0.0
# 1644          Fred Hoiberg          52.0
# 1650         Fred Saunders           0.0
# 1655         Fred VanVleet           0.0
# 1657          Freddie Boyd           0.0
# 1659         Freddie Lewis           0.0
# 1660      Freeman Williams           8.0
# 1665           Gabe Pruitt          32.0
# 1667        Gail Goodrich*           0.0
# 1671             Gar Heard           0.0
# 1676           Garry Witts         103.0
# 1682           Gary Brokaw           0.0
# 1685          Gary Garland          30.0
# 1693       Gary Melchionni           0.0
# 1698          Gary Plummer          45.0
# 1720            Gene Short           9.0
# 1729          Geoff Huston          50.0
# 1730          Geoff Petrie           0.0
# 1742        George Gervin*           0.0
# 1746        George Johnson          12.0
# 1753        George McCloud           7.0
# 1754       George McGinnis           0.0
# 1770       George Thompson           0.0
# 1772          George Trapp           0.0
# 1780          Gerald Brown           0.0
# 1803       Glen Gondrezick          26.0
# 1808          Glenn Hansen          31.0
# 1809        Glenn McDonald           0.0
# 1815           Goo Kennedy           0.0
# 1832          Greg Ballard           4.0
# 1835           Greg Butler          37.0
# 1842          Greg Griffin          71.0
# 1845          Greg Jackson           0.0
# 1846           Greg Kelser           4.0
# 1853            Greg Smith           0.0
# 1864            Gus Bailey           0.0
# 1865            Gus Gerard          50.0
# 1868          Gus Williams          20.0
# 1890         Hamed Haddadi           0.0
# 1894           Hank Finkel           0.0
# 1901        Happy Hairston           0.0
# 1909          Harold Miner          12.0
# 1914           Harry Davis          33.0
# 1923       Harthorne Wingo           0.0
# 1924      Harvey Catchings           0.0
# 1930       Hawkeye Whitney          16.0
# 1935           Henry Bibby           0.0
# 1950          Herm Gilliam           0.0
# 1959       Hollis Copeland          46.0
# 1976         Howard Porter           0.0
# 1993             Ian Clark           0.0
# 1995           Ian Mahinmi          28.0
# 1997        Igor Rakocevic          51.0
# 2006           Ira Terrell          45.0
# 2012          Isaac Austin          48.0
# 2025          Ivan Johnson           0.0
# 2028         Ivano Newbill           0.0
# 2032          J.J. Hickson          19.0
# 2034           J.J. Redick          11.0
# 2037        J.R. Henderson          56.0
# 2040        JaJuan Johnson          27.0
# 2047          Jabari Smith          45.0
# 2058           Jack Givens          16.0
# 2064            Jack Marin           0.0
# 2073            Jack Sikma           8.0
# 2082         Jackie Butler           0.0
# 2092         Jacque Vaughn          27.0
# 2110       Jamaal Magloire          19.0
# 2113        Jamaal Wilkes*           0.0
# 2125          James Bailey           6.0
# 2129       James Donaldson          73.0
# 2130         James Edwards          46.0
# 2132          James Harden           3.0
# 2133           James Hardy          11.0
# 2145           James Silas           0.0
# 2150          James Wilkes          50.0
# 2153           James Young          17.0
# 2155           Jamie Feick          48.0
# 2160               Jan Van           0.0
# 2163         Jannero Pargo           0.0
# 2171         Jaren Jackson           0.0
# 2180          Jason Caffey          20.0
# 2196    Javaris Crittenton          19.0
# 2198         Jawann Oldham          41.0
# 2216             Jeff Cook          49.0
# 2225          Jeff Judkins          30.0
# 2226             Jeff Lamp          15.0
# 2231          Jeff Mullins           0.0
# 2234           Jeff Ruland          25.0
# 2235          Jeff Sanders          20.0
# 2244          Jeff Wilkins          37.0
# 2250      Jerald Honeycutt          38.0
# 2254           Jeremy Lamb          12.0
# 2261       Jermaine O'Neal          17.0
# 2264          Jerome Allen          49.0
# 2271         Jerome Jordan          44.0
# 2272         Jerome Kersey          46.0
# 2276      Jerome Whitehead          41.0
# 2277       Jerome Williams          26.0
# 2302        Jerry Sichting          82.0
# 2304          Jerry Sloan*           0.0
# 2309        Jerryd Bayless          11.0
# 2313            Jesse Dark           0.0
# 2314               Jim Ard           0.0
# 2317           Jim Barnett           0.0
# 2321            Jim Brewer           0.0
# 2326            Jim Chones           0.0
# 2327          Jim Cleamons           0.0
# 2328         Jim Creighton           0.0
# 2329             Jim Davis           0.0
# 2331            Jim Eakins           0.0
# 2332            Jim Farmer          20.0
# 2333               Jim Fox           0.0
# 2347               Jim Les          70.0
# 2352         Jim McDaniels           0.0
# 2353           Jim McElroy          38.0
# 2354         Jim McIlvaine          32.0
# 2355         Jim McMillian           0.0
# 2360             Jim Owens           0.0
# 2362            Jim Paxson          12.0
# 2363          Jim Petersen          51.0
# 2366             Jim Price           0.0
# 2374         Jim Spanarkel          16.0
# 2381        Jim Washington           0.0
# 2386          Jimmy Butler          30.0
# 2395           Jimmy Jones           0.0
# 2400          Jimmy Walker           0.0
# 2401           Jiri Welsch          16.0
# 2402                 Jo Jo           0.0
# 2408           Jodie Meeks          41.0
# 2409         Joe Alexander           8.0
# 2411             Joe Barry           0.0
# 2415            Joe Bryant          14.0
# 2436           Joe Hassett          52.0
# 2446       Joe Meriweather          11.0
# 2448              Joe Pace          76.0
# 2460             Joe Young           0.0
# 2465           Joel Kramer          63.0
# 2478           John Battle          84.0
# 2480            John Block           0.0
# 2482            John Brown           0.0
# 2491           John Crotty           0.0
# 2494             John Drew           0.0
# 2495            John Duren          19.0
# 2500         John Gianelli           0.0
# 2504        John Havlicek*           0.0
# 2508           John Hummer           0.0
# 2511          John Johnson           0.0
# 2513          John Kuester          53.0
# 2514          John Lambert          15.0
# 2515        John Laskowski          32.0
# 2517             John Long          29.0
# 2518            John Lucas           1.0
# 2524          John Mengelt           0.0
# 2531            John Olive         168.0
# 2532           John Paxson          19.0
# 2539            John Roche           0.0
# 2540             John Rudd          32.0
# 2546          John Shumate           0.0
# 2548           John Starks           0.0
# 2551         John Stroeder         168.0
# 2558          John Tschogl           0.0
# 2559           John Turner          20.0
# 2564           John Wetzel           0.0
# 2566       John Williamson           0.0
# 2574          Johnny Davis          22.0
# 2579           Johnny High          24.0
# 2587          Johnny Moore          43.0
# 2588        Johnny Neumann           0.0
# 2589         Johnny Newman          29.0
# 2598             Jon Barry          21.0
# 2603        Jon McGlocklin           0.0
# 2613          Jordan Adams          22.0
# 2619           Jordan Hill           8.0
# 2631            Josh Boone          23.0
# 2634            Josh Grant          43.0
# 2641        Josh McRoberts          37.0
# 2657        Julius Erving*           0.0
# 2663         Jumaine Jones          27.0
# 2664      Junior Bridgeman           8.0
# 2687  Kareem Abdul-Jabbar*           0.0
# 2688           Kareem Rush          20.0
# 2694            Kay Felder           0.0
# 2705        Keith Erickson           0.0
# 2706          Keith Herron          24.0
# 2711          Keith McLeod           0.0
# 2727         Kelvin Ransey           4.0
# 2728         Kelvin Upshaw           0.0
# 2734           Ken Charles           0.0
# 2736           Ken Durrett           0.0
# 2738           Ken Johnson          28.0
# 2758            Kenny Carr           6.0
# 2762           Kenny Green          12.0
# 2763           Kenny Higgs           0.0
# 2774        Kenny Williams          46.0
# 2775         Kent Bazemore           0.0
# 2776           Kent Benson           1.0
# 2781     Kermit Washington           0.0
# 2784          Kevin Brooks          18.0
# 2791          Kevin Grevey          18.0
# 2795           Kevin Jones           0.0
# 2797         Kevin Kunnert           0.0
# 2803          Kevin Martin          26.0
# 2806         Kevin McKenna          88.0
# 2809           Kevin Ollie           0.0
# 2810          Kevin Porter           0.0
# 2812         Kevin Restani           0.0
# 2815          Kevin Stacom           0.0
# 2826       Kiki Vandeweghe          11.0
# 2829           Kim English          44.0
# 2830            Kim Hughes           0.0
# 2849              Kurk Lee           0.0
# 2856           Kyle Korver          51.0
# 2859             Kyle Macy          22.0
# 2870          LaRue Martin           0.0
# 2874       Lamar Patterson          48.0
# 2880          Lance Blanks          26.0
# 2896           Larry Demic           9.0
# 2897            Larry Drew          17.0
# 2906           Larry Kenon           0.0
# 2908         Larry McNeill           0.0
# 2909        Larry Micheaux          29.0
# 2914           Larry Nance          20.0
# 2921           Larry Smith          24.0
# 2922         Larry Spriggs          81.0
# 2924          Larry Steele           0.0
# 2927          Larry Wright          14.0
# 2936      Lawrence Roberts          55.0
# 2937         Lazar Hayward          30.0
# 2948            Lee Nailon          43.0
# 2951          Lee Winfield           0.0
# 2956            Len Elmore           0.0
# 2957         Len Kosmalski           0.0
# 2960        Lenny Wilkens*           0.0
# 2968           Leon Benbow           0.0
# 2971          Leon Douglas           4.0
# 2975          Leonard Gray           0.0
# 2978           Leroy Combs          26.0
# 2979           Leroy Ellis           0.0
# 2982            Les Jepsen          28.0
# 2993      Lindsay Hairston          64.0
# 2996         Linton Townes          33.0
# 2998       Lionel Chalmers          33.0
# 2999        Lionel Hollins           6.0
# 3005            Lloyd Neal           0.0
# 3006          Lloyd Walton          40.0
# 3013        Lonnie Shelton          25.0
# 3015          Lonny Baxter          43.0
# 3018           Loren Woods          45.0
# 3021       Lorenzo Charles          41.0
# 3023         Lorenzo Romar         141.0
# 3025          Lou Amundson           0.0
# 3026            Lou Hudson           0.0
# 3030          Lou Williams           0.0
# 3032        Louie Dampier*           0.0
# 3033          Louie Nelson           0.0
# 3035             Louis Orr          29.0
# 3037           Lowes Moore          52.0
# 3039            Loy Vaught          13.0
# 3045        Lucious Harris          28.0
# 3046          Lucius Allen           0.0
# 3047          Luigi Datome           0.0
# 3052        Luke Harangody          52.0
# 3053          Luke Jackson          10.0
# 3058            Luke Witte           0.0
# 3065            Lynn Greer           0.0
# 3067             M.L. Carr           0.0
# 3071          Maciej Lampe          30.0
# 3072           Mack Calvin           0.0
# 3075        Magic Johnson*           0.0
# 3077           Major Jones          20.0
# 3090        Malik Hairston          48.0
# 3104       Marcelo Huertas           0.0
# 3106       Marco Belinelli          18.0
# 3126            Mario Elie         160.0
# 3128           Mario Kasun          40.0
# 3134          Mark Bradtke           0.0
# 3138            Mark Davis          79.0
# 3143      Mark Landsberger          35.0
# 3149        Mark Olberding           0.0
# 3151            Mark Price          25.0
# 3152          Mark Radford          53.0
# 3153          Mark Randall          26.0
# 3155       Mark Strickland           0.0
# 3157             Mark West          30.0
# 3163           Marko Milic          33.0
# 3167        Marlon Redmond          60.0
# 3168         Marques Bragg           0.0
# 3169       Marques Johnson           3.0
# 3172        Marquis Teague          29.0
# 3179       Martin Muursepp          25.0
# 3180        Martin Nessley         116.0
# 3181          Marty Byrnes          19.0
# 3189         Marvin Barnes           0.0
# 3190        Marvin Webster           3.0
# 3195           Matt Bonner          45.0
# 3202           Matt Guokas           0.0
# 3217        Maurice Cheeks          36.0
# 3220         Maurice Lucas           0.0
# 3221        Maurice Martin          16.0
# 3236           Mel Bennett           0.0
# 3237            Mel Counts           0.0
# 3240             Mel Davis           0.0
# 3261         Michael Adams          66.0
# 3266        Michael Brooks           9.0
# 3270        Michael Cooper          60.0
# 3273        Michael Doleac          12.0
# 3278       Michael Jackson          47.0
# 3289         Michael Wiley          39.0
# 3292           Micheal Ray           0.0
# 3294      Micheal Williams          48.0
# 3298          Mickey Davis           0.0
# 3299        Mickey Dillard          55.0
# 3300        Mickey Johnson           0.0
# 3302           Mike Bantom           0.0
# 3303             Mike Barr           0.0
# 3308            Mike Bratz          66.0
# 3314         Mike D'Antoni           0.0
# 3317         Mike Dunleavy          99.0
# 3318            Mike Evans          21.0
# 3320            Mike Flynn         113.0
# 3321             Mike Gale           0.0
# 3322           Mike Gibson          44.0
# 3323            Mike Glenn          23.0
# 3324          Mike Gminski           7.0
# 3325            Mike Green           0.0
# 3328           Mike Harper          56.0
# 3342            Mike McGee          19.0
# 3344         Mike Mitchell          15.0
# 3347           Mike Newlin           0.0
# 3348            Mike Niles          83.0
# 3350          Mike O'Koren           6.0
# 3352        Mike Penberthy           0.0
# 3357          Mike Riordan           0.0
# 3358          Mike Sanders          74.0
# 3363        Mike Sojourner           0.0
# 3368            Mike Wilks           0.0
# 3370          Mike Woodson          12.0
# 3378          Milt Palacio           0.0
# 3385       Mirza Teletovic           0.0
# 3386         Mitch Kupchak          13.0
# 3392             Mo Howard          32.0
# 3393             Mo Layton           0.0
# 3395           Mo Williams          47.0
# 3402            Monte Towe          57.0
# 3406        Moochie Norris          33.0
# 3412         Moses Malone*           0.0
# 3418       Mychal Thompson           1.0
# 3435        Nate Hawthorne           0.0
# 3441        Nate Thurmond*           0.0
# 3442         Nate Williams           0.0
# 3448             Neal Walk           0.0
# 3455       Nemanja Bjelica          35.0
# 3472     Nick Weatherspoon           0.0
# 3493            Norm Nixon          22.0
# 3497              Norm Van           0.0
# 3507         Obinna Ekezie          37.0
# 3511           Okaro White           0.0
# 3512        Olden Polynice           8.0
# 3513      Oleksiy Pecherov          18.0
# 3516       Oliver Robinson          24.0
# 3519         Ollie Johnson           0.0
# 3520            Ollie Mack          25.0
# 3523             Omer Asik          36.0
# 3528       Orlando Johnson          36.0
# 3538         Otis Birdsong           2.0
# 3542            Otto Moore           0.0
# 3543           Otto Porter           3.0
# 3545            Owen Wells           0.0
# 3551          Pace Mannion          43.0
# 3557       Pat Connaughton          41.0
# 3558          Pat Cummings          59.0
# 3564            Pat Riley*           0.0
# 3566      Patrick Beverley          42.0
# 3576           Patty Mills           0.0
# 3581            Paul Davis          34.0
# 3582          Paul Dawkins         185.0
# 3588          Paul Griffin          74.0
# 3594        Paul McPherson           0.0
# 3596          Paul Mokeski          42.0
# 3607            Paul Silas           0.0
# 3611         Paul Westphal           0.0
# 3621            Perry Moss          69.0
# 3631        Pete Maravich*           0.0
# 3632            Pete Myers         120.0
# 3644          Phil Chenier           0.0
# 3646             Phil Ford           2.0
# 3648            Phil Hicks          61.0
# 3649          Phil Hubbard          15.0
# 3651         Phil Jackson*           0.0
# 3653          Phil Lumpkin           0.0
# 3657          Phil Sellers          38.0
# 3658            Phil Smith           0.0
# 3659           Phil Walker         117.0
# 3675     Priest Lauderdale          28.0
# 3677          Purvis Short           5.0
# 3679            Quincy Acy          37.0
# 3680          Quincy Douby          19.0
# 3681          Quincy Lewis          19.0
# 3684         Quinn Buckner           7.0
# 3688          Qyntel Woods          21.0
# 3690           R.J. Hunter          28.0
# 3707           Ralph Lewis         139.0
# 3714         Ralph Simpson           0.0
# 3720         Randolph Keys          22.0
# 3725           Randy Brown          31.0
# 3726          Randy Denton           0.0
# 3729      Randy Livingston          42.0
# 3731           Randy Smith           0.0
# 3761           Ray Tolbert          18.0
# 3762          Ray Williams          10.0
# 3765      Raymond Townsend          22.0
# 3779        Reggie Bullock          25.0
# 3780         Reggie Carter          27.0
# 3782          Reggie Geary          56.0
# 3785        Reggie Jackson          24.0
# 3786        Reggie Johnson          15.0
# 3788           Reggie King          18.0
# 3790          Reggie Lewis          22.0
# 3796          Reggie Theus           9.0
# 3802           Rex Walters          16.0
# 3806            Rich Jones           0.0
# 3807           Rich Kelley           7.0
# 3827    Richard Washington           3.0
# 3829          Richie Frahm           0.0
# 3834          Rick Adelman           0.0
# 3836           Rick Barry*           0.0
# 3838         Rick Calloway           0.0
# 3839         Rick Carlisle          70.0
# 3843           Rick Mahorn          35.0
# 3846         Rick Roberson           0.0
# 3847            Rick Robey           3.0
# 3849           Rick Wilson          25.0
# 3850          Rickey Brown          13.0
# 3851          Rickey Green          16.0
# 3852       Rickey Williams         190.0
# 3859           Ricky Marsh         165.0
# 3862          Ricky Sobers          16.0
# 3875        Robert Hawkins          51.0
# 3879           Robert Pack           0.0
# 3881        Robert Parish*           0.0
# 3882           Robert Reid          40.0
# 3884          Robert Smith          65.0
# 3890           Robin Jones           0.0
# 3893           Rod Derline           0.0
# 3901         Rodney Buford          53.0
# 3906         Rodney Monroe          30.0
# 3912           Roger Brown           0.0
# 3916           Roger Mason          30.0
# 3917         Roger Phegley          14.0
# 3921             Roko Ukic          41.0
# 3929           Ron Behagen           0.0
# 3931             Ron Boone           0.0
# 3932            Ron Brewer           7.0
# 3933            Ron Carter          26.0
# 3936             Ron Davis          70.0
# 3940         Ron Grandison         100.0
# 3947               Ron Lee          10.0
# 3955             Ron Riley           0.0
# 3962          Ron Williams           0.0
# 3980            Rory White          86.0
# 3981        Roshown McLeod          20.0
# 3982       Rowland Garrett           0.0
# 3985          Roy Hamilton          10.0
# 4005           Rudy Gobert          27.0
# 4009      Rudy Tomjanovich           0.0
# 4010            Rudy White          47.0
# 4016         Russell Cross           6.0
# 4021            Ryan Bowen          55.0
# 4039             Sam Lacey           0.0
# 4040              Sam Mack           0.0
# 4042            Sam Pellom           0.0
# 4048           Sam Vincent          20.0
# 4050           Sam Worthen          26.0
# 4054      Samuel Dalembert          26.0
# 4067          Scot Pollard          19.0
# 4074           Scott Lloyd          24.0
# 4076             Scott May           2.0
# 4082          Scott Wedman           0.0
# 4083        Scott Williams           0.0
# 4085       Scottie Pippen*           0.0
# 4089            Sean Green          41.0
# 4090          Sean Higgins          54.0
# 4091       Sean Kilpatrick           0.0
# 4092          Sean Lampley          44.0
# 4099        Sedale Threatt         139.0
# 4104           Serge Ibaka          24.0
# 4110      Shabazz Muhammad          14.0
# 4114      Shandon Anderson          54.0
# 4117            Shane Heal           0.0
# 4118          Shane Larkin          18.0
# 4119         Shannon Brown          25.0
# 4131         Shawn Respert           8.0
# 4133       Shawnelle Scott          43.0
# 4141          Shelvin Mack          34.0
# 4149          Sidney Green           5.0
# 4151       Sidney Moncrief           5.0
# 4152          Sidney Wicks           0.0
# 4169           Slick Watts           0.0
# 4170          Sly Williams          21.0
# 4177          Sonny Parker          17.0
# 4179       Soumaila Samake          36.0
# 4184      Spencer Haywood*           0.0
# 4197      Stan Pietkiewicz         133.0
# 4211        Stephen Howard           0.0
# 4223          Steve Bracey           0.0
# 4225           Steve Burtt          30.0
# 4231           Steve Green          30.0
# 4235          Steve Harris          19.0
# 4236           Steve Hawes           0.0
# 4237           Steve Hayes          76.0
# 4238          Steve Henson          44.0
# 4240           Steve Jones           0.0
# 4243        Steve Kuberski           0.0
# 4245         Steve Malovic         149.0
# 4247             Steve Mix           0.0
# 4250       Steve Patterson           0.0
# 4251       Steve Scheffler          39.0
# 4252        Steve Sheppard          30.0
# 4264      Stojko Vrankovic           0.0
# 4266             Stu Lantz           0.0
# 4267           Stuart Gray          29.0
# 4269       Sundiata Gaines           0.0
# 4271            Swen Nater           0.0
# 4278             T.R. Dunn          41.0
# 4280           Tal Skinner           0.0
# 4281            Tamar Slay          53.0
# 4286        Tate Armstrong          13.0
# 4294           Ted McClain           0.0
# 4314          Terry Duerod          48.0
# 4315          Terry Furlow          12.0
# 4319          Terry Rozier          16.0
# 4322           Terry Tyler          23.0
# 4335       Thomas Robinson           5.0
# 4340          Ticky Burden          26.0
# 4342           Tim Bassett           0.0
# 4347             Tim James          25.0
# 4349            Tim Legler           0.0
# 4359       Tiny Archibald*           0.0
# 4360          Tito Horford          39.0
# 4365           Toby Knight          32.0
# 4372            Todd Mundt           0.0
# 4374         Tom Abernethy          43.0
# 4375            Tom Barker          53.0
# 4377        Tom Boerwinkle           0.0
# 4378           Tom Boswell          17.0
# 4380          Tom Burleson           0.0
# 4393         Tom Henderson           0.0
# 4402           Tom Kozelko           0.0
# 4403             Tom Kropp          48.0
# 4404           Tom LaGarde           9.0
# 4406          Tom McMillen           0.0
# 4408             Tom Owens           0.0
# 4412             Tom Riker           0.0
# 4415         Tom Scheffler         117.0
# 4417             Tom Sluby          41.0
# 4421               Tom Van           0.0
# 4426          Tommie Green          35.0
# 4441         Tony Campbell          20.0
# 4444            Tony Dumas          19.0
# 4454       Tony Massenburg          43.0
# 4458        Tony Robertson          88.0
# 4461            Tony White          33.0
# 4463           Tony Wroten          25.0
# 4469          Toure' Murry           0.0
# 4470         Tracy Jackson          25.0
# 4484       Travis Williams           0.0
# 4485          Tree Rollins          14.0
# 4503          Troy Daniels           0.0
# 4508        Truck Robinson           0.0
# 4526        Tyshawn Taylor          41.0
# 4530            Tyus Jones          24.0
# 4533              Uwe Blab          17.0
# 4538    Vassilis Spanoulis          50.0
# 4557          Vince Taylor          34.0
# 4560     Vincenzo Esposito           0.0
# 4561        Vinnie Johnson           7.0
# 4573         Voshon Lenard          46.0
# 4585          Wally Walker           5.0
# 4591         Walt Frazier*           0.0
# 4598           Walt Wesley           0.0
# 4603          Walter Davis           5.0
# 4608        Walter McCarty          19.0
# 4614           Wang Zhizhi          36.0
# 4616       Wardell Jackson           0.0
# 4627          Wayne Cooper          40.0
# 4636         Wayne Radford          27.0
# 4637        Wayne Robinson          31.0
# 4638       Wayne Sappleton          38.0
# 4647          Wes Matthews          14.0
# 4650           Wes Unseld*           0.0
# 4652            Wesley Cox          18.0
# 4663             Wil Jones           0.0
# 4667        Wilbur Holland          75.0
# 4668            Wiley Peck          19.0
# 4675           Will Perdue          11.0
# 4687          Willie Green          41.0
# 4694        Willie Norwood           0.0
# 4699          Willie Smith          18.0
# 4703          Willie White          42.0
# 4705           Willie Wise           0.0
# 4712     Wilson Washington          25.0
# 4716        Winford Boynes          13.0
# 4722              World B.           0.0
# 4744         Zach Randolph          19.0
# 4745       Zaid Abdul-Aziz           0.0
# 4746             Zan Tabak          51.0
# 4754          Zelmo Beaty*           0.0
#
#                                                 college  height  weight  \
# 8                                  University of Oregon     6.0   160.6
# 12                           Grambling State University     6.7   209.0
# 18                     University of Wisconsin-Parkside     6.7   209.0
# 28                               University of Maryland     6.6   182.6
# 29                                     Lamar University     6.7   264.0
# 31                                                    0     6.4   206.8
# 43                               University of Missouri     6.5   224.4
# 48                                                    0     6.8   228.8
# 61                  University of Massachusetts Amherst     6.2   189.2
# 68                                      Duke University     6.8   237.6
# 70                               University of Michigan     6.6   193.6
# 74              University of California, Santa Barbara     6.5   198.0
# 78                               University of Colorado     6.5   213.4
# 87                                 Villanova University     6.5   189.2
# 90                                                    0     6.6   189.2
# 108                        Loyola University of Chicago     6.5   202.4
# 109   Virginia Polytechnic Institute and State Unive...     6.6   209.0
# 115                            Oklahoma City University     6.1   169.4
# 118                           Texas Southern University     6.5   189.2
# 123                               University of Houston     6.1   189.2
# 125                              University of Oklahoma     6.8   209.0
# 130                             Oral Roberts University     6.6   182.6
# 135                                                   0     6.8   237.6
# 136                                                   0     6.8   270.6
# 137                                  Indiana University     6.8   235.4
# 141                                   DePaul University     6.8   244.2
# 146               University of California, Los Angeles     6.2   189.2
# 154                        Loyola University of Chicago     6.2   173.8
# 162                                                   0     7.0   283.8
# 165                               College of Charleston     6.2   198.0
# 170                University of Louisiana at Lafayette     6.2   176.0
# 183                                  Niagara University     6.3   189.2
# 191                     University of Nevada, Las Vegas     6.7   244.2
# 193                              University of Oklahoma     6.5   189.2
# 198                               Pepperdine University     6.6   202.4
# 203                          Tennessee State University     6.6   248.6
# 206                                  Bradley University     6.5   213.4
# 211                             Oral Roberts University     6.4   182.6
# 220                                Texas A&M University     6.6   209.0
# 227                                     Duke University     6.9   244.2
# 231                             University of Minnesota     6.2   173.8
# 233                              University of Kentucky     6.4   198.0
# 239                          University of Nevada, Reno     6.4   235.4
# 240                                Princeton University     6.3   189.2
# 241                        Mississippi State University     6.9   246.4
# 260                                                   0     7.2   237.6
# 270                            Jackson State University     6.8   228.8
# 273                            University of Notre Dame     6.3   198.0
# 277                       University of Texas at Austin     6.2   178.2
# 278                 Southern University and A&M College     5.8   173.8
# 281                                  University of Iowa     6.6   224.4
# 287               University of California, Los Angeles     6.2   206.8
# 288                            Ohio Wesleyan University     6.5   209.0
# 298                   University of Nebraska at Kearney     6.3   209.0
# 301                             Grand Canyon University     6.8   233.2
# 315                         Central Michigan University     6.8   233.2
# 319                                 University of Tulsa     6.2   202.4
# 320                           Virginia Union University     6.8   237.6
# 327                                                   0     6.6   202.4
# 329                 California State University, Fresno     6.5   209.0
# 331                            Brigham Young University     6.2   182.6
# 339                                                   0     6.4   202.4
# 341                                University of Kansas     6.5   226.6
# 345                         University of San Francisco     7.1   244.2
# 359                            University of Notre Dame     6.6   182.6
# 365                                  University of Iowa     6.6   173.8
# 367                            University of Notre Dame     6.9   244.2
# 368                               Vanderbilt University     6.3   178.2
# 369                               Georgetown University     6.6   202.4
# 378                                   DePaul University     6.6   228.8
# 390                                                   0     6.9   209.0
# 392                                                   0     6.7   202.4
# 395                                                   0     6.5   209.0
# 397                                  Providence College     5.9   169.4
# 403                            University of Pittsburgh     6.5   193.6
# 404                             Northwestern University     6.0   158.4
# 406                               St. John's University     6.9   233.2
# 407                                                   0     6.8   217.8
# 409                         University of San Francisco     6.4   189.2
# 413                            University of Louisville     6.6   193.6
# 415                                 University of Tulsa     6.4   189.2
# 416                               Pepperdine University     6.1   169.4
# 425                                Marquette University     6.4   182.6
# 428                University of Louisiana at Lafayette     6.1   178.2
# 436                          University of Pennsylvania     6.6   213.4
# 443                                      Boston College     6.5   193.6
# 448                            Norfolk State University     6.5   193.6
# 456                               University of Arizona     6.8   224.4
# 465             California State University, Long Beach     6.5   198.0
# 466                                  University of Iowa     6.5   189.2
# 474                                    Guilford College     6.7   237.6
# 479                                                   0     6.9   248.6
# 482                 Southern University and A&M College     6.7   213.4
# 485                                                   0     6.8   209.0
# ...
# 443   0.0  22.96
# 448   0.0  37.89
# 456   0.0  13.37
# 465   0.0  19.39
# 466   0.0   7.62
# 474   0.0  10.92
# 479   0.0  39.30
# 482   0.0  39.36
# 485   0.0  43.16
# 492   0.0  12.12
# 516   0.0  17.61
# 518   0.0  19.90
# 525   0.0   6.88
# 534   0.0  29.50
# 538   0.0   4.48
# 547   0.0   8.85
# 552   0.0  17.61
# 560   0.0  10.12
# 561   0.0   5.18
# 563   0.0  12.34
# 571   0.0   5.60
# 573   0.0  11.27
# 602   0.0   6.23
# 604   0.0  15.21
# 608   0.0  34.56
# 609   0.0  22.29
# 621   0.0  30.06
# 630   0.0  12.97
# 631   0.0   7.92
# 646   0.0  22.85
# 652   0.0  30.74
# 654   0.0  12.44
# 655   0.0  10.15
# 658   0.0  21.70
# 662   0.0   9.06
# 663   0.0  10.97
# 668   0.0  11.07
# 669   0.0  12.53
# 671   0.0  11.50
# 674   0.0   9.20
# 678   0.0  24.67
# 682   0.0  23.40
# 685   0.0  32.22
# 686   0.0  36.63
# 690   0.0  11.09
# 691   0.0  14.97
# 699   0.0  16.93
# 702   0.0  16.55
# 704   0.0   9.91
# 709   0.0   4.10
# 719   0.0  15.93
# 722   0.0  26.38
# 727   0.0  11.59
# 732   0.0  16.85
# 734   0.0  23.51
# 737   0.0   8.61
# 747   0.0  11.28
# 751   0.0  27.48
# 754   0.0   7.80
# 758   0.0   8.07
# 760   0.0   4.33
# 765   0.0  25.13
# 772   0.0  37.57
# 773   0.0   7.07
# 790   0.0  32.26
# 805   0.0   6.40
# 810   0.0  24.53
# 811   0.0   7.71
# 818   0.0   9.47
# 841   0.0  11.71
# 856   0.0  13.38
# 860   0.0   6.51
# 865   0.0  17.62
# 866   0.0  13.34
# 868   0.0  19.83
# 874   0.0   7.09
# 880   0.0  12.11
# 882   0.0   9.31
# 884   0.0  10.03
# 885   0.0  10.73
# 894   0.0  15.69
# 895   0.0  17.68
# 896   0.0  23.73
# 899   0.0  30.72
# 900   0.0  19.09
# 904   0.0  19.00
# 906   0.0   8.32
# 907   0.0   8.69
# 911   0.0  32.10
# 914   0.0  14.58
# 915   0.0  21.61
# 918   0.0   8.62
# 921   0.0   5.98
# 924   0.0  23.86
# 925   0.0  12.58
# 931   0.0   6.43
# 932   0.0  10.53
# 934   0.0   6.91
# 936   0.0  19.69
# 940   0.0  31.89
# 943   0.0   9.33
# 944   0.0   9.18
# 946   0.0  11.13
# 959   0.0   3.22
# 960   0.0   4.20
# 962   0.0   9.43
# 964   0.0  10.65
# 972   0.0  34.03
# 973   0.0  33.99
# 980   0.0   8.18
# 983   0.0   9.20
# 992   0.0  12.66
# 994   0.0   7.40
# 1002  0.0   5.67
# 1009  0.0  10.53
# 1011  0.0  10.30
# 1016  0.0  31.73
# 1019  0.0   7.30
# 1024  0.0  26.97
# 1063  0.0   4.68
# 1064  0.0  28.07
# 1066  0.0   7.50
# 1070  0.0  15.07
# 1074  0.0  35.40
# 1077  0.0  16.15
# 1079  0.0  15.65
# 1085  0.0   4.46
# 1089  0.0  24.44
# 1092  0.0  40.78
# 1096  0.0   9.02
# 1098  0.0  40.49
# 1105  0.0  34.04
# 1109  0.0   5.46
# 1110  0.0   8.48
# 1113  0.0  22.07
# 1118  0.0  24.58
# 1123  0.0  26.18
# 1124  0.0  22.96
# 1126  0.0  14.14
# 1134  0.0  11.65
# 1137  0.0   9.36
# 1144  0.0  36.60
# 1146  0.0   8.06
# 1148  0.0   9.03
# 1159  0.0   4.41
# 1168  0.0  11.00
# 1170  0.0  27.21
# 1172  0.0   9.78
# 1178  0.0  12.78
# 1180  0.0   9.49
# 1188  0.0  34.60
# 1189  0.0   8.94
# 1191  0.0   3.70
# 1198  0.0  20.58
# 1202  0.0  13.08
# 1208  0.0  17.12
# 1219  0.0  23.24
# 1221  0.0   9.39
# 1223  0.0   5.24
# 1226  0.0   6.27
# 1246  0.0  10.81
# 1260  0.0   6.61
# 1262  0.0  14.76
# 1273  0.0   7.19
# 1291  0.0  31.59
# 1294  0.0  34.56
# 1309  0.0   6.39
# 1322  0.0  26.98
# 1329  0.0  36.38
# 1332  0.0  26.93
# 1333  0.0  22.78
# 1336  0.0  24.18
# 1346  0.0  25.97
# 1355  0.0   9.96
# 1358  0.0  11.30
# 1369  0.0  23.13
# 1370  0.0   6.12
# 1372  0.0  11.39
# 1381  0.0  12.28
# 1384  0.0  34.81
# 1385  0.0   5.58
# 1388  0.0   6.67
# 1389  0.0   8.92
# 1392  0.0   9.81
# 1395  0.0   7.27
# 1397  0.0  13.35
# 1401  0.0  12.56
# 1406  0.0   9.92
# 1407  0.0   5.63
# 1411  0.0  23.30
# 1412  0.0  24.72
# 1416  0.0   8.43
# 1424  0.0  25.18
# 1426  0.0  27.81
# 1431  0.0   8.71
# 1432  0.0  28.26
# 1435  0.0   7.51
# 1436  0.0  10.15
# 1438  0.0  10.58
# 1445  0.0  36.08
# 1447  0.0  18.37
# 1448  0.0  15.06
# 1449  0.0  13.16
# 1479  0.0  32.04
# 1489  0.0  11.00
# 1491  0.0  23.73
# 1493  0.0  16.62
# 1500  0.0   8.67
# 1503  0.0  15.83
# 1510  0.0   4.11
# 1512  0.0   7.31
# 1519  0.0   8.74
# 1525  0.0  31.64
# 1532  0.0  42.26
# 1535  0.0  13.31
# 1538  0.0  13.24
# 1543  0.0   7.24
# 1546  0.0  10.39
# 1550  0.0  13.47
# 1553  0.0   9.56
# 1558  0.0  11.47
# 1570  0.0  22.97
# 1571  0.0  17.27
# 1581  0.0  13.15
# 1587  0.0   5.97
# 1591  0.0   8.31
# 1593  0.0  19.59
# 1596  0.0   2.39
# 1603  0.0  14.86
# 1617  0.0   7.68
# 1622  0.0  12.50
# 1634  0.0  10.41
# 1636  0.0  32.95
# 1637  0.0  39.56
# 1641  0.0  15.56
# 1644  0.0  12.17
# 1650  0.0  15.35
# 1655  0.0   7.95
# 1657  0.0  20.64
# 1659  0.0  17.25
# 1660  0.0  16.60
# 1665  0.0   7.79
# 1667  0.0  37.06
# 1671  0.0  32.06
# 1676  0.0  10.72
# 1682  0.0  22.45
# 1685  0.0  14.18
# 1693  0.0  22.49
# 1698  0.0  10.64
# 1720  0.0   6.53
# 1729  0.0  13.00
# 1730  0.0  38.86
# 1742  0.0  32.99
# 1746  0.0  17.55
# 1753  0.0   9.39
# 1754  0.0  38.26
# 1770  0.0  27.16
# 1772  0.0  18.87
# 1780  0.0   7.15
# 1803  0.0  14.13
# 1808  0.0  17.35
# 1809  0.0   6.37
# 1815  0.0   8.66
# 1832  0.0  12.32
# 1835  0.0   4.24
# 1842  0.0  11.72
# 1845  0.0  16.37
# 1846  0.0  24.66
# 1853  0.0   9.44
# 1864  0.0   9.49
# 1865  0.0  16.12
# 1868  0.0  22.44
# 1890  0.0   6.67
# 1894  0.0   8.35
# 1901  0.0  30.85
# 1909  0.0  18.95
# 1914  0.0   9.85
# 1923  0.0  20.56
# 1924  0.0  14.27
# 1930  0.0  16.64
# 1935  0.0  18.67
# 1950  0.0  23.22
# 1959  0.0  15.23
# 1976  0.0  20.05
# 1993  0.0   6.40
# 1995  0.0   8.71
# 1997  0.0   5.81
# 2006  0.0  22.45
# 2012  0.0   3.61
# 2025  0.0  16.68
# 2028  0.0   9.74
# 2032  0.0  11.37
# 2034  0.0  14.81
# 2037  0.0  11.03
# 2040  0.0   8.28
# 2047  0.0   5.42
# 2058  0.0  18.20
# 2064  0.0  26.51
# 2073  0.0  27.29
# 2082  0.0  13.45
# 2092  0.0   9.31
# 2110  0.0  14.80
# 2113  0.0  30.67
# 2125  0.0  10.84
# 2129  0.0  14.41
# 2130  0.0  28.98
# 2132  0.0  22.87
# 2133  0.0  21.41
# 2145  0.0   8.41
# 2150  0.0  11.25
# 2153  0.0  10.71
# 2155  0.0  16.16
# 2160  0.0  33.31
# 2163  0.0  10.06
# 2171  0.0  10.29
# 2180  0.0   9.56
# 2196  0.0  13.58
# 2198  0.0  13.59
# 2216  0.0  13.70
# 2225  0.0  18.78
# 2226  0.0  11.43
# 2231  0.0  17.29
# 2234  0.0  27.00
# 2235  0.0   5.87
# 2244  0.0  18.89
# 2250  0.0  13.95
# 2254  0.0  19.72
# 2261  0.0  10.18
# 2264  0.0   8.83
# 2271  0.0   8.70
# 2272  0.0  12.44
# 2276  0.0   4.90
# 2277  0.0   5.36
# 2302  0.0   9.57
# 2304  0.0  33.04
# 2309  0.0  12.36
# 2313  0.0   8.53
# 2314  0.0  12.19
# 2317  0.0  24.33
# 2321  0.0  24.28
# 2326  0.0  33.71
# 2327  0.0  36.36
# 2328  0.0   5.38
# 2329  0.0  13.65
# 2331  0.0  16.32
# 2332  0.0   5.23
# 2333  0.0  23.55
# 2347  0.0   9.52
# 2352  0.0   6.91
# 2353  0.0  22.24
# 2354  0.0   9.71
# 2355  0.0  34.39
# 2360  0.0  10.54
# 2362  0.0  17.64
# 2363  0.0  11.90
# 2366  0.0  37.40
# 2374  0.0  11.05
# 2381  0.0  19.74
# 2386  0.0   8.55
# 2395  0.0  19.51
# 2400  0.0  38.54
# 2401  0.0   6.32
# 2402  0.0  39.27
# 2408  0.0  11.98
# 2409  0.0  12.14
# 2411  0.0  35.60
# 2415  0.0  16.04
# 2436  0.0   8.42
# 2446  0.0  25.21
# 2448  0.0   8.94
# 2460  0.0   9.37
# 2465  0.0  17.09
# 2478  0.0   9.98
# 2480  0.0  17.39
# 2482  0.0  27.21
# 2491  0.0   6.08
# 2494  0.0  29.35
# 2495  0.0  11.45
# 2500  0.0  34.96
# 2504  0.0  38.20
# 2508  0.0  13.21
# 2511  0.0  31.75
# 2513  0.0  15.58
# 2514  0.0   6.17
# 2515  0.0  22.11
# 2517  0.0  30.46
# 2518  0.0  30.87
# 2524  0.0  24.94
# 2531  0.0   5.56
# 2532  0.0   9.35
# 2539  0.0  27.88
# 2540  0.0  12.47
# 2546  0.0  26.35
# 2548  0.0   8.78
# 2551  0.0   6.61
# 2558  0.0  15.97
# 2559  0.0   8.21
# 2564  0.0  12.46
# 2566  0.0  34.46
# 2574  0.0  18.37
# 2579  0.0  13.67
# 2587  0.0  19.24
# 2588  0.0  14.87
# 2589  0.0  10.68
# 2598  0.0  11.74
# 2603  0.0  23.46
# 2613  0.0   8.27
# 2619  0.0  13.28
# 2631  0.0  10.97
# 2634  0.0   7.21
# 2641  0.0   8.45
# 2657  0.0  35.85
# 2663  0.0   4.18
# 2664  0.0  20.32
# 2687  0.0  42.26
# 2688  0.0  11.47
# 2694  0.0   9.19
# 2705  0.0  29.98
# 2706  0.0  28.38
# 2711  0.0  11.85
# 2727  0.0  30.39
# 2728  0.0  19.28
# 2734  0.0  21.39
# 2736  0.0   9.27
# 2738  0.0  12.73
# 2758  0.0  14.10
# 2762  0.0  11.05
# 2763  0.0  15.44
# 2774  0.0   7.03
# 2775  0.0   4.38
# 2776  0.0  18.67
# 2781  0.0  17.25
# 2784  0.0   7.30
# 2791  0.0   9.00
# 2795  0.0  10.44
# 2797  0.0  24.01
# 2803  0.0  10.11
# 2806  0.0   6.58
# 2809  0.0  12.29
# 2810  0.0  31.96
# 2812  0.0  23.09
# 2815  0.0   7.33
# 2826  0.0  26.98
# 2829  0.0   9.93
# 2830  0.0  25.69
# 2849  0.0   5.52
# 2856  0.0  11.92
# 2859  0.0  17.91
# 2870  0.0  16.94
# 2874  0.0  11.29
# 2880  0.0   5.63
# 2896  0.0  22.83
# 2897  0.0  20.80
# 2906  0.0  37.64
# 2908  0.0  21.86
# 2909  0.0   8.51
# 2914  0.0  14.83
# 2921  0.0  31.44
# 2922  0.0   9.55
# 2924  0.0  31.43
# 2927  0.0  18.22
# 2936  0.0   5.48
# 2937  0.0   9.98
# 2948  0.0  11.17
# 2951  0.0  18.51
# 2956  0.0  19.23
# 2957  0.0   6.16
# 2960  0.0  17.86
# 2968  0.0   6.46
# 2971  0.0  19.83
# 2975  0.0  30.40
# 2978  0.0   9.29
# 2979  0.0  26.62
# 2982  0.0   2.81
# 2993  0.0  13.85
# 2996  0.0   9.38
# 2998  0.0  12.03
# 2999  0.0  25.55
# 3005  0.0  27.78
# 3006  0.0  12.79
# 3013  0.0  25.66
# 3015  0.0  12.40
# 3018  0.0   8.60
# 3021  0.0   7.58
# 3023  0.0  13.70
# 3025  0.0  13.74
# 3026  0.0  31.58
# 3030  0.0   4.83
# 3032  0.0  20.43
# 3033  0.0  26.36
# 3035  0.0  21.79
# 3037  0.0  19.80
# 3039  0.0  16.14
# 3045  0.0  15.13
# 3046  0.0  35.65
# 3047  0.0   7.00
# 3052  0.0  13.06
# 3053  0.0   8.75
# 3058  0.0   6.95
# 3065  0.0  10.54
# 3067  0.0  32.23
# 3071  0.0  10.27
# 3072  0.0  18.92
# 3075  0.0  36.30
# 3077  0.0  18.84
# 3090  0.0   6.74
# 3104  0.0  16.40
# 3106  0.0   7.30
# 3126  0.0  20.80
# 3128  0.0   7.91
# 3134  0.0   6.97
# 3138  0.0   7.82
# 3143  0.0  14.94
# 3149  0.0  23.77
# 3151  0.0  18.16
# 3152  0.0   8.58
# 3153  0.0   8.17
# 3155  0.0   4.94
# 3157  0.0   5.94
# 3163  0.0   4.94
# 3167  0.0  14.32
# 3168  0.0   6.96
# 3169  0.0  34.56
# 3172  0.0   8.17
# 3179  0.0   8.29
# 3180  0.0   7.64
# 3181  0.0  16.00
# 3189  0.0  18.66
# 3190  0.0  15.95
# 3195  0.0  18.94
# 3202  0.0  25.48
# 3217  0.0  29.38
# 3220  0.0  36.24
# 3221  0.0   6.65
# 3236  0.0  13.60
# 3237  0.0  18.95
# 3240  0.0  14.56
# 3261  0.0  20.68
# 3266  0.0  30.23
# 3270  0.0  24.06
# 3273  0.0  15.92
# 3278  0.0  13.10
# 3289  0.0   8.21
# 3292  0.0  16.92
# 3294  0.0   7.31
# 3298  0.0  14.36
# 3299  0.0   6.70
# 3300  0.0   7.66
# 3302  0.0  27.30
# 3303  0.0  16.77
# 3308  0.0  11.66
# 3314  0.0  11.33
# 3317  0.0  11.22
# 3318  0.0  15.77
# 3320  0.0  18.14
# 3321  0.0  31.68
# 3322  0.0   7.16
# 3323  0.0  16.91
# 3324  0.0  28.20
# 3325  0.0  25.37
# 3328  0.0   8.38
# 3342  0.0   9.03
# 3344  0.0  19.70
# 3347  0.0  34.29
# 3348  0.0   5.25
# 3350  0.0  31.30
# 3352  0.0  16.06
# 3357  0.0  29.61
# 3358  0.0  11.72
# 3363  0.0  29.16
# 3368  0.0  10.45
# 3370  0.0  11.72
# 3378  0.0   7.43
# 3385  0.0   9.42
# 3386  0.0  18.45
# 3392  0.0  10.78
# 3393  0.0  13.66
# 3395  0.0  13.54
# 3402  0.0   8.02
# 3406  0.0  16.73
# 3412  0.0  30.56
# 3418  0.0  29.37
# 3435  0.0  12.36
# 3441  0.0  34.45
# 3442  0.0  22.88
# 3448  0.0  16.79
# 3455  0.0  17.92
# 3472  0.0  16.43
# 3493  0.0  34.31
# 3497  0.0  37.00
# 3507  0.0   9.00
# 3511  0.0  13.46
# 3512  0.0  13.17
# 3513  0.0   9.14
# 3516  0.0   4.20
# 3519  0.0  22.84
# 3520  0.0  13.62
# 3523  0.0  12.06
# 3528  0.0  12.14
# 3538  0.0  25.73
# 3542  0.0  25.38
# 3543  0.0   8.62
# 3545  0.0   6.48
# 3551  0.0   8.23
# 3557  0.0   4.21
# 3558  0.0  12.68
# 3564  0.0  22.09
# 3566  0.0  17.39
# 3576  0.0  12.23
# 3581  0.0   5.81
# 3582  0.0  13.61
# 3588  0.0  20.31
# 3594  0.0  10.82
# 3596  0.0  22.69
# 3607  0.0  32.45
# 3611  0.0  19.28
# 3621  0.0  14.06
# 3631  0.0  36.11
# 3632  0.0   8.18
# 3644  0.0  37.26
# 3646  0.0  34.47
# 3648  0.0   7.08
# 3649  0.0  18.58
# 3651  0.0  29.29
# 3653  0.0  16.50
# 3657  0.0   7.48
# 3658  0.0  14.26
# 3659  0.0   9.60
# 3675  0.0   5.14
# 3677  0.0  22.71
# 3679  0.0  13.44
# 3680  0.0   8.55
# 3681  0.0  12.11
# 3684  0.0  26.52
# 3688  0.0   6.30
# 3690  0.0   8.75
# 3707  0.0   6.20
# 3714  0.0  20.74
# 3720  0.0   7.88
# 3725  0.0   9.55
# 3726  0.0  15.56
# 3729  0.0  15.33
# 3731  0.0  36.60
# 3761  0.0   9.48
# 3762  0.0  19.14
# 3765  0.0  11.86
# 3779  0.0   9.19
# 3780  0.0   8.93
# 3782  0.0   6.31
# 3785  0.0  11.13
# 3786  0.0  21.72
# 3788  0.0  25.02
# 3790  0.0   8.27
# 3796  0.0  33.57
# 3802  0.0   8.04
# 3806  0.0  25.79
# 3807  0.0  17.95
# 3827  0.0  27.62
# 3829  0.0   8.69
# 3834  0.0  18.52
# 3836  0.0  40.44
# 3838  0.0  10.59
# 3839  0.0   4.71
# 3843  0.0  13.38
# 3846  0.0   9.58
# 3847  0.0  22.32
# 3849  0.0   9.66
# 3850  0.0  12.89
# 3851  0.0  14.45
# 3852  0.0   7.86
# 3859  0.0  14.18
# 3862  0.0  24.33
# 3875  0.0   4.78
# 3879  0.0  12.42
# 3881  0.0  17.97
# 3882  0.0  23.11
# 3884  0.0   8.40
# 3890  0.0  16.90
# 3893  0.0  11.48
# 3901  0.0  11.35
# 3906  0.0   8.24
# 3912  0.0   7.49
# 3916  0.0   7.94
# 3917  0.0  19.38
# 3921  0.0  12.36
# 3929  0.0  27.22
# 3931  0.0  36.84
# 3932  0.0  30.30
# 3933  0.0   7.22
# 3936  0.0  12.77
# 3940  0.0   7.33
# 3947  0.0  22.55
# 3955  0.0  20.49
# 3962  0.0  11.43
# 3980  0.0   9.63
# 3981  0.0  10.24
# 3982  0.0  16.90
# 3985  0.0  15.50
# 4005  0.0   9.64
# 4009  0.0  38.69
# 4010  0.0   8.88
# 4016  0.0   7.87
# 4021  0.0  11.33
# 4039  0.0  41.70
# 4040  0.0   6.68
# 4042  0.0   8.48
# 4048  0.0   7.58
# 4050  0.0  14.77
# 4054  0.0   5.21
# 4067  0.0   9.61
# 4074  0.0  14.86
# 4076  0.0  32.90
# 4082  0.0  31.93
# 4083  0.0   6.61
# 4085  0.0  20.89
# 4089  0.0   7.31
# 4090  0.0   9.28
# 4091  0.0  19.87
# 4092  0.0  13.91
# 4099  0.0  10.31
# 4104  0.0  18.12
# 4110  0.0   7.84
# 4114  0.0  16.40
# 4117  0.0   5.49
# 4118  0.0  10.19
# 4119  0.0   9.94
# 4131  0.0  13.63
# 4133  0.0   4.59
# 4141  0.0  12.17
# 4149  0.0  13.61
# 4151  0.0  20.22
# 4152  0.0  38.56
# 4169  0.0  25.07
# 4170  0.0   9.75
# 4177  0.0  13.68
# 4179  0.0   6.65
# 4184  0.0  37.19
# 4197  0.0  11.54
# 4211  0.0   5.31
# 4223  0.0   8.10
# 4225  0.0   8.89
# 4231  0.0  13.11
# 4235  0.0   8.46
# 4236  0.0  16.31
# 4237  0.0  13.91
# 4238  0.0  10.15
# 4240  0.0  12.80
# 4243  0.0   8.76
# 4245  0.0  11.41
# 4247  0.0  38.00
# 4250  0.0  15.67
# 4251  0.0   5.82
# 4252  0.0  10.91
# 4264  0.0   5.35
# 4266  0.0  23.77
# 4267  0.0   7.52
# 4269  0.0   6.78
# 4271  0.0  27.22
# 4278  0.0  12.19
# 4280  0.0  21.56
# 4281  0.0   7.61
# 4286  0.0  10.85
# 4294  0.0  27.81
# 4314  0.0  19.87
# 4315  0.0   5.44
# 4319  0.0   7.97
# 4322  0.0  31.22
# 4335  0.0  15.09
# 4340  0.0   9.97
# 4342  0.0  32.13
# 4347  0.0   6.57
# 4349  0.0  19.24
# 4359  0.0  39.56
# 4360  0.0   6.74
# 4365  0.0  14.61
# 4372  0.0   4.58
# 4374  0.0  19.69
# 4375  0.0  22.95
# 4377  0.0  14.69
# 4378  0.0   7.86
# 4380  0.0  23.02
# 4393  0.0  26.97
# 4402  0.0  10.33
# 4403  0.0   9.06
# 4404  0.0  11.27
# 4406  0.0  14.16
# 4408  0.0  10.04
# 4412  0.0   9.47
# 4415  0.0   6.87
# 4417  0.0   4.87
# 4421  0.0  34.67
# 4426  0.0  13.71
# 4441  0.0  11.16
# 4444  0.0  10.57
# 4454  0.0   4.60
# 4458  0.0  14.75
# 4461  0.0  11.86
# 4463  0.0   7.77
# 4469  0.0   7.31
# 4470  0.0   9.76
# 4484  0.0   9.36
# 4485  0.0  22.44
# 4503  0.0   8.45
# 4508  0.0  13.09
# 4526  0.0   5.82
# 4530  0.0  15.49
# 4533  0.0   8.52
# 4538  0.0   8.77
# 4557  0.0  10.35
# 4560  0.0   9.40
# 4561  0.0   8.55
# 4573  0.0  10.77
# 4585  0.0   9.50
# 4591  0.0  41.08
# 4598  0.0   5.49
# 4603  0.0  31.98
# 4608  0.0   5.49
# 4614  0.0  10.91
# 4616  0.0  16.77
# 4627  0.0  12.23
# 4636  0.0  12.48
# 4637  0.0  19.65
# 4638  0.0   9.03
# 4647  0.0  28.68
# 4650  0.0  39.78
# 4652  0.0  10.53
# 4663  0.0  33.86
# 4667  0.0  10.64
# 4668  0.0  12.08
# 4675  0.0   6.33
# 4687  0.0  14.47
# 4694  0.0  15.69
# 4699  0.0  16.95
# 4703  0.0   6.00
# 4705  0.0  18.71
# 4712  0.0  14.76
# 4716  0.0  17.04
# 4722  0.0  15.79
# 4744  0.0   5.80
# 4745  0.0  22.31
# 4746  0.0   4.92
# 4754  0.0  17.58
